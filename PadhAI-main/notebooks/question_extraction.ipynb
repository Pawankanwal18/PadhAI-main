# %% [markdown]
# # Question & Topic Extraction
#
# This notebook extracts questions and topics from PDFs and writes an aggregated CSV suitable for training an exam-question predictor.

# %%
import sys
import subprocess
# Install dependencies (uncomment to run)
# subprocess.check_call([sys.executable, '-m', 'pip', 'install', '--user', '-r', 'requirements.txt'])

# %%
import sys, subprocess, os
script = os.path.join('scripts', 'extract_questions_from_pdf.py')
out_csv = os.path.join('data', 'training-dataset.csv')
# Run on current directory (processes all PDFs recursively)
subprocess.check_call([sys.executable, script, '.', '--out', out_csv])
print('Wrote:', out_csv)
